# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsippel/colab/blob/main/assets/Applio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Applio**
# A simple, high-quality voice conversion tool focused on ease of use and performance.
#
# [Support](https://discord.gg/urxFjYmYYh) — [GitHub](https://github.com/IAHispano/Applio) — [Terms of Use](https://github.com/IAHispano/Applio/blob/main/TERMS_OF_USE.md)
#
# <br>
#
# ---
#
# <br>
#
# #### **Acknowledgments**
#
# To all external collaborators for their special help in the following areas: Hina (Encryption method), Poopmaster (Extra section), Shirou (UV installer)
#
# #### **Disclaimer**
# By using Applio, you agree to comply with ethical and legal standards, respect intellectual property and privacy rights, avoid harmful or prohibited uses, and accept full responsibility for any outcomes, while Applio disclaims liability and reserves the right to amend these terms.

# %%
# @title **Install Applio**
import sys
from IPython.display import clear_output
import codecs
import os

encoded_url = "uggcf://tvguho.pbz/VNUvfcnab/Nccyvb/"
decoded_url = codecs.decode(encoded_url, "rot_13")

repo_name_encoded = "Nccyvb"
repo_name = codecs.decode(repo_name_encoded, "rot_13")

# !pip install -q uv

# !git clone --depth 1 {decoded_url} --branch 3.2.9 --single-branch
# %cd {repo_name}
clear_output()

print("Installing requirements...")
# !uv pip install torch==2.7.1 torchvision torchaudio==2.7.1 \
  --index-url https://download.pytorch.org/whl/cu128 \
  -q
# !uv pip install -r requirements.txt -q
# !uv pip install pyngrok -q

clear_output()
print("✅ Finished installing requirements!")
# Out:
# ✅ Finished installing requirements!

# %%
# @title **Start Applio**
# @markdown  ### Choose a sharing method:

import codecs
import threading
import urllib.request
import time
import ipywidgets as widgets
from IPython.display import display
import os
from pyngrok import ngrok
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

method = "gradio"  # @param ["gradio", "localtunnel", "ngrok"]
ngrok_token = "If you selected the 'ngrok' method, obtain your auth token here: https://dashboard.ngrok.com/get-started/your-authtoken" # @param {type:"string"}
tensorboard = False #@param {type: "boolean"}

def start_gradio():
    # !python app.py --listen --share

def start_localtunnel():
    # !npm install -g localtunnel &>/dev/null
    with open('url.txt', 'w') as file:
        file.write('')
    get_ipython().system_raw('lt --port 6969 >> url.txt 2>&1 &')
    time.sleep(2)
    endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n")

    with open('url.txt', 'r') as file:
        tunnel_url = file.read()
        tunnel_url = tunnel_url.replace("your url is: ", "")

    print(f"Share Link: \033[0m\033[93m{tunnel_url}\033[0m", end="\033[0m\n")

    password_endpoint_widget = widgets.Text(
    value=endpoint_ip,
    description='Password IP:',
    disabled=True
    )
    display(password_endpoint_widget)
    # !python app.py --listen


def start_ngrok():
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: \033[0m\033[93m{tunnel.public_url}\033[0m", end="\033[0m\n")
        # !python app.py --listen
    except Exception as e:
        print(f"Error starting ngrok: {e}")

def start_applio():
    if method == 'gradio':
        start_gradio()
    elif method == 'localtunnel':
        start_localtunnel()
    elif method == 'ngrok':
        start_ngrok()

if tensorboard:
    # %load_ext tensorboard
    # %reload_ext tensorboard
    # %tensorboard --logdir logs --bind_all

if "autobackups" not in globals():
    autobackups = False

if autobackups:
    thread = threading.Thread(target=backup_files)
    thread.start()

thread_applio = threading.Thread(target=start_applio)
thread_applio.start()


while True:
    time.sleep(5)
# Out:
# Starting backup loop...
# Files are up to date.
# An error occurred connecting to Discord: Could not find Discord installed and running on this machine.
# * Running on local URL:  http://127.0.0.1:6969
# * Running on public URL: https://5c62ca7f0c239f17c3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Starting preprocess with 12 processes...
# 100% 19/19 [00:03<00:00,  5.92it/s]
# Preprocess completed in 3.21 seconds on 00:33:19 seconds of audio.
# Starting pitch extraction with 12 cores on cuda:0 using rmvpe...
# Backup Complete: 1232 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   0% 0/616 [00:00<?, ?it/s]Files are up to date.
#  18% 112/616 [00:04<00:16, 31.47it/s]Backup Complete: 1393 new, 1 updated, 0 deleted.
#  31% 189/616 [00:06<00:14, 28.68it/s]Backup Complete: 163 new, 1 updated, 0 deleted.
#  42% 259/616 [00:08<00:11, 30.53it/s]Backup Complete: 145 new, 0 updated, 0 deleted.
#  54% 334/616 [00:11<00:09, 30.16it/s]Backup Complete: 148 new, 0 updated, 0 deleted.
#  66% 409/616 [00:13<00:06, 31.32it/s]Backup Complete: 148 new, 0 updated, 0 deleted.
#  80% 490/616 [00:16<00:03, 34.54it/s]Backup Complete: 153 new, 0 updated, 0 deleted.
# 100% 616/616 [00:19<00:00, 30.87it/s]
# Backup Complete: 202 new, 0 updated, 0 deleted.
# Pitch extraction completed in 26.05 seconds.
# Starting embedding extraction with 12 cores on cuda:0...
# Backup Complete: 329 new, 0 updated, 0 deleted.
# Backup Complete: 112 new, 0 updated, 0 deleted.
# Backup Complete: 138 new, 0 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# 100% 616/616 [00:09<00:00, 66.59it/s]
# Embedding extraction completed in 14.41 seconds.
# Backup Complete: 616 new, 2 updated, 0 deleted.
# Files are up to date.
# Backup Complete: 616 new, 2 updated, 0 deleted.
# Files are up to date.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127280.027432   41964 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127280.034101   41964 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Removing files from the prior training attempt...
# Cleanup done!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127285.846118   42027 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127285.852461   42027 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using HiFi-GAN vocoder
# Starting training...
# Loaded pretrained (G) 'rvc/models/pretraineds/hifi-gan/f0G40k.pth'
# Loaded pretrained (D) 'rvc/models/pretraineds/hifi-gan/f0D40k.pth'
# Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127294.365862   42114 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127294.372260   42114 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127300.181457   42177 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127300.187952   42177 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127305.946291   42247 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127305.952677   42247 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751127311.813751   42331 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751127311.820210   42331 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#  28% 5/18 [00:15<00:29,  2.23s/it]Backup Complete: 611 new, 0 updated, 0 deleted.
# Backup Complete: 611 new, 0 updated, 0 deleted.
#  33% 6/18 [00:17<00:24,  2.07s/it]Files are up to date.
#  39% 7/18 [00:18<00:17,  1.60s/it]Files are up to date.
# zwanglos-v3-meta_glasses | epoch=1 | step=18 | time=16:15:47 | training_speed=0:00:28 | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=0.000 | smoothed_loss_disc=0.000
#  50% 9/18 [00:05<00:05,  1.64it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
#  56% 10/18 [00:06<00:05,  1.58it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
#  61% 11/18 [00:06<00:04,  1.56it/s]Files are up to date.
#  67% 12/18 [00:07<00:03,  1.59it/s]Files are up to date.
# New best epoch 2 with smoothed loss_g 31.828 and loss_d 4.043
# zwanglos-v3-meta_glasses | epoch=2 | step=36 | time=16:15:58 | training_speed=0:00:11 | lowest_value=31.828 (epoch 2 and step 30) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.828 | smoothed_loss_disc=4.043
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_2e_36s_best_epoch.pth' (epoch 2 and step 36)
# New best epoch 3 with smoothed loss_g 31.815 and loss_d 4.045
# zwanglos-v3-meta_glasses | epoch=3 | step=54 | time=16:16:10 | training_speed=0:00:11 | lowest_value=30.818 (epoch 3 and step 38) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.815 | smoothed_loss_disc=4.045
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_3e_54s_best_epoch.pth' (epoch 3 and step 54)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 1/18 [00:00<00:10,  1.59it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  11% 2/18 [00:01<00:09,  1.61it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.64it/s]Files are up to date.
#  22% 4/18 [00:02<00:08,  1.66it/s]Files are up to date.
# New best epoch 4 with smoothed loss_g 31.789 and loss_d 4.050
# zwanglos-v3-meta_glasses | epoch=4 | step=72 | time=16:16:21 | training_speed=0:00:11 | lowest_value=29.791 (epoch 4 and step 71) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.789 | smoothed_loss_disc=4.050
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_4e_72s_best_epoch.pth' (epoch 4 and step 72)
#  61% 11/18 [00:06<00:04,  1.68it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  67% 12/18 [00:07<00:03,  1.68it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  72% 13/18 [00:07<00:02,  1.68it/s]Files are up to date.
#  78% 14/18 [00:08<00:02,  1.68it/s]Files are up to date.
# New best epoch 5 with smoothed loss_g 31.759 and loss_d 4.047
# zwanglos-v3-meta_glasses | epoch=5 | step=90 | time=16:16:33 | training_speed=0:00:11 | lowest_value=29.535 (epoch 5 and step 79) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.759 | smoothed_loss_disc=4.047
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_5e_90s_best_epoch.pth' (epoch 5 and step 90)
# New best epoch 6 with smoothed loss_g 31.716 and loss_d 4.046
# zwanglos-v3-meta_glasses | epoch=6 | step=108 | time=16:16:44 | training_speed=0:00:11 | lowest_value=28.413 (epoch 6 and step 93) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.716 | smoothed_loss_disc=4.046
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_6e_108s_best_epoch.pth' (epoch 6 and step 108)
#  11% 2/18 [00:01<00:09,  1.62it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  17% 3/18 [00:01<00:09,  1.64it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  22% 4/18 [00:02<00:08,  1.64it/s]Files are up to date.
#  28% 5/18 [00:03<00:08,  1.59it/s]Files are up to date.
# New best epoch 7 with smoothed loss_g 31.673 and loss_d 4.046
# zwanglos-v3-meta_glasses | epoch=7 | step=126 | time=16:16:56 | training_speed=0:00:11 | lowest_value=28.413 (epoch 6 and step 93) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.673 | smoothed_loss_disc=4.046
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_7e_126s_best_epoch.pth' (epoch 7 and step 126)
#  67% 12/18 [00:07<00:03,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  72% 13/18 [00:07<00:03,  1.64it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
#  78% 14/18 [00:08<00:02,  1.63it/s]Files are up to date.
# New best epoch 8 with smoothed loss_g 31.624 and loss_d 4.047
# zwanglos-v3-meta_glasses | epoch=8 | step=144 | time=16:17:07 | training_speed=0:00:11 | lowest_value=27.935 (epoch 8 and step 127) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.624 | smoothed_loss_disc=4.047
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_8e_144s_best_epoch.pth' (epoch 8 and step 144)
# New best epoch 9 with smoothed loss_g 31.565 and loss_d 4.050
# zwanglos-v3-meta_glasses | epoch=9 | step=162 | time=16:17:19 | training_speed=0:00:11 | lowest_value=27.068 (epoch 9 and step 161) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.565 | smoothed_loss_disc=4.050
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_9e_162s_best_epoch.pth' (epoch 9 and step 162)
#  11% 2/18 [00:01<00:09,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  22% 4/18 [00:02<00:08,  1.65it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
#  33% 6/18 [00:03<00:07,  1.67it/s]Files are up to date.
# New best epoch 10 with smoothed loss_g 31.507 and loss_d 4.054
# zwanglos-v3-meta_glasses | epoch=10 | step=180 | time=16:17:34 | training_speed=0:00:15 | lowest_value=27.068 (epoch 9 and step 161) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.507 | smoothed_loss_disc=4.054
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 10)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 10)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_10e_180s_best_epoch.pth' (epoch 10 and step 180)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_10e_180s.pth' (epoch 10 and step 180)
#  61% 11/18 [00:06<00:04,  1.59it/s]Backup Complete: 5 new, 1 updated, 1 deleted.
#  89% 16/18 [00:09<00:01,  1.63it/s]Backup Complete: 5 new, 1 updated, 0 deleted.
# New best epoch 11 with smoothed loss_g 31.449 and loss_d 4.054
# zwanglos-v3-meta_glasses | epoch=11 | step=198 | time=16:17:47 | training_speed=0:00:11 | lowest_value=27.068 (epoch 9 and step 161) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.449 | smoothed_loss_disc=4.054
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_11e_198s_best_epoch.pth' (epoch 11 and step 198)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  11% 2/18 [00:01<00:10,  1.57it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 3/18 [00:02<00:11,  1.26it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  28% 5/18 [00:03<00:09,  1.43it/s]Files are up to date.
# Files are up to date.
# New best epoch 12 with smoothed loss_g 31.392 and loss_d 4.053
# zwanglos-v3-meta_glasses | epoch=12 | step=216 | time=16:17:59 | training_speed=0:00:11 | lowest_value=27.068 (epoch 9 and step 161) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.392 | smoothed_loss_disc=4.053
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_12e_216s_best_epoch.pth' (epoch 12 and step 216)
#  72% 13/18 [00:07<00:03,  1.65it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  83% 15/18 [00:09<00:02,  1.43it/s]Files are up to date.
# Files are up to date.
# New best epoch 13 with smoothed loss_g 31.336 and loss_d 4.051
# zwanglos-v3-meta_glasses | epoch=13 | step=234 | time=16:18:11 | training_speed=0:00:11 | lowest_value=27.068 (epoch 9 and step 161) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.336 | smoothed_loss_disc=4.051
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_13e_234s_best_epoch.pth' (epoch 13 and step 234)
#  61% 11/18 [00:06<00:04,  1.64it/s]Saved index file '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses.index'
# New best epoch 14 with smoothed loss_g 31.269 and loss_d 4.055
# zwanglos-v3-meta_glasses | epoch=14 | step=252 | time=16:18:22 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.269 | smoothed_loss_disc=4.055
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_14e_252s_best_epoch.pth' (epoch 14 and step 252)
#  33% 6/18 [00:03<00:07,  1.64it/s]Backup Complete: 2 new, 1 updated, 1 deleted.
# Backup Complete: 2 new, 1 updated, 0 deleted.
#  39% 7/18 [00:04<00:07,  1.38it/s]Files are up to date.
# Files are up to date.
# New best epoch 15 with smoothed loss_g 31.202 and loss_d 4.056
# zwanglos-v3-meta_glasses | epoch=15 | step=270 | time=16:18:34 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.202 | smoothed_loss_disc=4.056
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_15e_270s_best_epoch.pth' (epoch 15 and step 270)
#  89% 16/18 [00:09<00:01,  1.69it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# New best epoch 16 with smoothed loss_g 31.137 and loss_d 4.056
# zwanglos-v3-meta_glasses | epoch=16 | step=288 | time=16:18:46 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.137 | smoothed_loss_disc=4.056
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_16e_288s_best_epoch.pth' (epoch 16 and step 288)
# New best epoch 17 with smoothed loss_g 31.072 and loss_d 4.055
# zwanglos-v3-meta_glasses | epoch=17 | step=306 | time=16:18:57 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.072 | smoothed_loss_disc=4.055
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_17e_306s_best_epoch.pth' (epoch 17 and step 306)
#  39% 7/18 [00:04<00:06,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  50% 9/18 [00:05<00:05,  1.62it/s]Files are up to date.
# Files are up to date.
# New best epoch 18 with smoothed loss_g 31.008 and loss_d 4.056
# zwanglos-v3-meta_glasses | epoch=18 | step=324 | time=16:19:09 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=31.008 | smoothed_loss_disc=4.056
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_18e_324s_best_epoch.pth' (epoch 18 and step 324)
#  94% 17/18 [00:10<00:00,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# New best epoch 19 with smoothed loss_g 30.945 and loss_d 4.058
# zwanglos-v3-meta_glasses | epoch=19 | step=342 | time=16:19:20 | training_speed=0:00:11 | lowest_value=26.16 (epoch 14 and step 247) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.945 | smoothed_loss_disc=4.058
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_19e_342s_best_epoch.pth' (epoch 19 and step 342)
#   6% 1/18 [00:00<00:10,  1.57it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.63it/s]Files are up to date.
# Files are up to date.
#  89% 16/18 [00:09<00:01,  1.67it/s]Using HiFi-GAN vocoder
# New best epoch 20 with smoothed loss_g 30.874 and loss_d 4.057
# zwanglos-v3-meta_glasses | epoch=20 | step=360 | time=16:19:32 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.874 | smoothed_loss_disc=4.057
# Converting audio 'assets/audios/Oimara_-_Wackelkontakt_vocals.mp3'...
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 20)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 20)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_20e_360s_best_epoch.pth' (epoch 20 and step 360)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_20e_360s.pth' (epoch 20 and step 360)
#  22% 4/18 [00:03<00:13,  1.07it/s]Conversion completed at 'assets/audios/Oimara_-_Wackelkontakt_vocals_output.wav' in 6.44 seconds.
#  89% 16/18 [00:11<00:01,  1.45it/s]Backup Complete: 2 new, 4 updated, 1 deleted.
# Backup Complete: 2 new, 4 updated, 0 deleted.
# New best epoch 21 with smoothed loss_g 30.803 and loss_d 4.059
# zwanglos-v3-meta_glasses | epoch=21 | step=378 | time=16:19:48 | training_speed=0:00:13 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.803 | smoothed_loss_disc=4.059
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_21e_378s_best_epoch.pth' (epoch 21 and step 378)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#  83% 15/18 [00:09<00:01,  1.68it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  89% 16/18 [00:09<00:01,  1.69it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  94% 17/18 [00:10<00:00,  1.65it/s]Files are up to date.
# Files are up to date.
# New best epoch 22 with smoothed loss_g 30.733 and loss_d 4.058
# zwanglos-v3-meta_glasses | epoch=22 | step=396 | time=16:19:59 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.733 | smoothed_loss_disc=4.058
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_22e_396s_best_epoch.pth' (epoch 22 and step 396)
# New best epoch 23 with smoothed loss_g 30.665 and loss_d 4.060
# zwanglos-v3-meta_glasses | epoch=23 | step=414 | time=16:20:10 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.665 | smoothed_loss_disc=4.060
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_23e_414s_best_epoch.pth' (epoch 23 and step 414)
#  33% 6/18 [00:03<00:07,  1.64it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  44% 8/18 [00:04<00:06,  1.63it/s]Files are up to date.
# New best epoch 24 with smoothed loss_g 30.597 and loss_d 4.060
# zwanglos-v3-meta_glasses | epoch=24 | step=432 | time=16:20:22 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.597 | smoothed_loss_disc=4.060
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_24e_432s_best_epoch.pth' (epoch 24 and step 432)
#  83% 15/18 [00:08<00:01,  1.67it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  89% 16/18 [00:09<00:01,  1.66it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  94% 17/18 [00:10<00:00,  1.64it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 1 deleted.
# New best epoch 25 with smoothed loss_g 30.530 and loss_d 4.061
# zwanglos-v3-meta_glasses | epoch=25 | step=450 | time=16:20:33 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.530 | smoothed_loss_disc=4.061
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_25e_450s_best_epoch.pth' (epoch 25 and step 450)
#   6% 1/18 [00:00<00:10,  1.60it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  11% 2/18 [00:01<00:09,  1.62it/s]Files are up to date.
#  17% 3/18 [00:01<00:09,  1.65it/s]Files are up to date.
# New best epoch 26 with smoothed loss_g 30.464 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=26 | step=468 | time=16:20:45 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.464 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_26e_468s_best_epoch.pth' (epoch 26 and step 468)
#  56% 10/18 [00:05<00:04,  1.68it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  61% 11/18 [00:06<00:04,  1.68it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  67% 12/18 [00:07<00:03,  1.65it/s]Files are up to date.
#  72% 13/18 [00:07<00:03,  1.61it/s]Files are up to date.
# New best epoch 27 with smoothed loss_g 30.399 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=27 | step=486 | time=16:20:56 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.399 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_27e_486s_best_epoch.pth' (epoch 27 and step 486)
# New best epoch 28 with smoothed loss_g 30.334 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=28 | step=504 | time=16:21:08 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.334 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_28e_504s_best_epoch.pth' (epoch 28 and step 504)
#   6% 1/18 [00:00<00:10,  1.58it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  11% 2/18 [00:01<00:10,  1.60it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.63it/s]Files are up to date.
#  22% 4/18 [00:02<00:08,  1.65it/s]Files are up to date.
# New best epoch 29 with smoothed loss_g 30.271 and loss_d 4.062
# zwanglos-v3-meta_glasses | epoch=29 | step=522 | time=16:21:20 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.271 | smoothed_loss_disc=4.062
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_29e_522s_best_epoch.pth' (epoch 29 and step 522)
#  61% 11/18 [00:06<00:04,  1.68it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  67% 12/18 [00:07<00:03,  1.69it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  72% 13/18 [00:07<00:02,  1.68it/s]Files are up to date.
#  78% 14/18 [00:08<00:02,  1.67it/s]Files are up to date.
# New best epoch 30 with smoothed loss_g 30.208 and loss_d 4.061
# zwanglos-v3-meta_glasses | epoch=30 | step=540 | time=16:21:31 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.208 | smoothed_loss_disc=4.061
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 30)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 30)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_30e_540s_best_epoch.pth' (epoch 30 and step 540)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_30e_540s.pth' (epoch 30 and step 540)
# New best epoch 31 with smoothed loss_g 30.146 and loss_d 4.061
# zwanglos-v3-meta_glasses | epoch=31 | step=558 | time=16:21:45 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.146 | smoothed_loss_disc=4.061
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_31e_558s_best_epoch.pth' (epoch 31 and step 558)
#  44% 8/18 [00:04<00:06,  1.64it/s]Backup Complete: 2 new, 4 updated, 2 deleted.
#  56% 10/18 [00:06<00:04,  1.63it/s]Backup Complete: 2 new, 4 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  72% 13/18 [00:07<00:03,  1.65it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  78% 14/18 [00:08<00:02,  1.66it/s]Files are up to date.
#  83% 15/18 [00:09<00:01,  1.66it/s]Files are up to date.
# New best epoch 32 with smoothed loss_g 30.085 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=32 | step=576 | time=16:21:57 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.085 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_32e_576s_best_epoch.pth' (epoch 32 and step 576)
# New best epoch 33 with smoothed loss_g 30.025 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=33 | step=594 | time=16:22:08 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=30.025 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_33e_594s_best_epoch.pth' (epoch 33 and step 594)
#  17% 3/18 [00:01<00:09,  1.62it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  22% 4/18 [00:02<00:08,  1.57it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  28% 5/18 [00:03<00:08,  1.60it/s]Files are up to date.
#  33% 6/18 [00:03<00:07,  1.62it/s]Files are up to date.
# New best epoch 34 with smoothed loss_g 29.965 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=34 | step=612 | time=16:22:20 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.965 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_34e_612s_best_epoch.pth' (epoch 34 and step 612)
# New best epoch 35 with smoothed loss_g 29.907 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=35 | step=630 | time=16:22:31 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.907 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_35e_630s_best_epoch.pth' (epoch 35 and step 630)
#  33% 6/18 [00:03<00:07,  1.54it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_34e_612s_best_epoch.pth'
# An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_34e_612s_best_epoch.pth'
#  44% 8/18 [00:05<00:06,  1.61it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  56% 10/18 [00:06<00:04,  1.66it/s]Files are up to date.
# Files are up to date.
# New best epoch 36 with smoothed loss_g 29.849 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=36 | step=648 | time=16:22:43 | training_speed=0:00:11 | lowest_value=25.449 (epoch 20 and step 346) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.849 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_36e_648s_best_epoch.pth' (epoch 36 and step 648)
# Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# New best epoch 37 with smoothed loss_g 29.789 and loss_d 4.062
# zwanglos-v3-meta_glasses | epoch=37 | step=666 | time=16:22:54 | training_speed=0:00:11 | lowest_value=25.243 (epoch 37 and step 655) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.789 | smoothed_loss_disc=4.062
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_37e_666s_best_epoch.pth' (epoch 37 and step 666)
#   6% 1/18 [00:00<00:10,  1.60it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.62it/s]Files are up to date.
# Files are up to date.
# New best epoch 38 with smoothed loss_g 29.730 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=38 | step=684 | time=16:23:06 | training_speed=0:00:11 | lowest_value=25.243 (epoch 37 and step 655) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.730 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_38e_684s_best_epoch.pth' (epoch 38 and step 684)
#  61% 11/18 [00:06<00:04,  1.50it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  72% 13/18 [00:08<00:03,  1.57it/s]Files are up to date.
# Files are up to date.
# New best epoch 39 with smoothed loss_g 29.671 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=39 | step=702 | time=16:23:17 | training_speed=0:00:11 | lowest_value=25.243 (epoch 37 and step 655) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.671 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_39e_702s_best_epoch.pth' (epoch 39 and step 702)
# New best epoch 40 with smoothed loss_g 29.614 and loss_d 4.065
# zwanglos-v3-meta_glasses | epoch=40 | step=720 | time=16:23:29 | training_speed=0:00:11 | lowest_value=25.243 (epoch 37 and step 655) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.614 | smoothed_loss_disc=4.065
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 40)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 40)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_40e_720s_best_epoch.pth' (epoch 40 and step 720)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_40e_720s.pth' (epoch 40 and step 720)
#  33% 6/18 [00:04<00:07,  1.56it/s]Backup Complete: 0 new, 4 updated, 1 deleted.
#  44% 8/18 [00:05<00:06,  1.59it/s]Backup Complete: 0 new, 4 updated, 0 deleted.
#  50% 9/18 [00:05<00:05,  1.59it/s]Backup Complete: 2 new, 0 updated, 0 deleted.
#  61% 11/18 [00:07<00:04,  1.64it/s]Files are up to date.
#  67% 12/18 [00:07<00:03,  1.64it/s]Backup Complete: 2 new, 0 updated, 0 deleted.
#  72% 13/18 [00:08<00:03,  1.65it/s]Files are up to date.
# New best epoch 41 with smoothed loss_g 29.557 and loss_d 4.067
# zwanglos-v3-meta_glasses | epoch=41 | step=738 | time=16:23:44 | training_speed=0:00:11 | lowest_value=25.243 (epoch 37 and step 655) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.557 | smoothed_loss_disc=4.067
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_41e_738s_best_epoch.pth' (epoch 41 and step 738)
# An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_41e_738s_best_epoch.pth'
# New best epoch 42 with smoothed loss_g 29.501 and loss_d 4.066
# zwanglos-v3-meta_glasses | epoch=42 | step=756 | time=16:23:55 | training_speed=0:00:11 | lowest_value=25.211 (epoch 42 and step 755) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.501 | smoothed_loss_disc=4.066
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_42e_756s_best_epoch.pth' (epoch 42 and step 756)
#   6% 1/18 [00:00<00:10,  1.59it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  11% 2/18 [00:01<00:09,  1.62it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.59it/s]Files are up to date.
#  22% 4/18 [00:02<00:08,  1.59it/s]Files are up to date.
# New best epoch 43 with smoothed loss_g 29.445 and loss_d 4.066
# zwanglos-v3-meta_glasses | epoch=43 | step=774 | time=16:24:07 | training_speed=0:00:11 | lowest_value=25.211 (epoch 42 and step 755) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.445 | smoothed_loss_disc=4.066
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_43e_774s_best_epoch.pth' (epoch 43 and step 774)
# New best epoch 44 with smoothed loss_g 29.389 and loss_d 4.067
# zwanglos-v3-meta_glasses | epoch=44 | step=792 | time=16:24:18 | training_speed=0:00:11 | lowest_value=25.113 (epoch 44 and step 790) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.389 | smoothed_loss_disc=4.067
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_44e_792s_best_epoch.pth' (epoch 44 and step 792)
#  33% 6/18 [00:03<00:07,  1.68it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_43e_774s_best_epoch.pth'
# An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_43e_774s_best_epoch.pth'
#  44% 8/18 [00:04<00:06,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  50% 9/18 [00:05<00:05,  1.63it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  56% 10/18 [00:06<00:04,  1.64it/s]Files are up to date.
#  61% 11/18 [00:06<00:04,  1.64it/s]Files are up to date.
# New best epoch 45 with smoothed loss_g 29.331 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=45 | step=810 | time=16:24:30 | training_speed=0:00:11 | lowest_value=24.974 (epoch 45 and step 799) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.331 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_45e_810s_best_epoch.pth' (epoch 45 and step 810)
# Backup Complete: 1 new, 1 updated, 1 deleted.
# New best epoch 46 with smoothed loss_g 29.275 and loss_d 4.065
# zwanglos-v3-meta_glasses | epoch=46 | step=828 | time=16:24:42 | training_speed=0:00:11 | lowest_value=24.974 (epoch 45 and step 799) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.275 | smoothed_loss_disc=4.065
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_46e_828s_best_epoch.pth' (epoch 46 and step 828)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 1/18 [00:00<00:10,  1.58it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  11% 2/18 [00:01<00:09,  1.66it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.66it/s]Files are up to date.
# Files are up to date.
# New best epoch 47 with smoothed loss_g 29.218 and loss_d 4.066
# zwanglos-v3-meta_glasses | epoch=47 | step=846 | time=16:24:53 | training_speed=0:00:11 | lowest_value=24.917 (epoch 47 and step 833) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.218 | smoothed_loss_disc=4.066
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_47e_846s_best_epoch.pth' (epoch 47 and step 846)
#  61% 11/18 [00:06<00:04,  1.70it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  72% 13/18 [00:07<00:02,  1.67it/s]Files are up to date.
# Files are up to date.
# New best epoch 48 with smoothed loss_g 29.162 and loss_d 4.065
# zwanglos-v3-meta_glasses | epoch=48 | step=864 | time=16:25:04 | training_speed=0:00:11 | lowest_value=24.917 (epoch 47 and step 833) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.162 | smoothed_loss_disc=4.065
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_48e_864s_best_epoch.pth' (epoch 48 and step 864)
# New best epoch 49 with smoothed loss_g 29.105 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=49 | step=882 | time=16:25:16 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.105 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_49e_882s_best_epoch.pth' (epoch 49 and step 882)
#  11% 2/18 [00:01<00:10,  1.56it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  22% 4/18 [00:02<00:08,  1.63it/s]Files are up to date.
# Files are up to date.
# New best epoch 50 with smoothed loss_g 29.049 and loss_d 4.065
# zwanglos-v3-meta_glasses | epoch=50 | step=900 | time=16:25:28 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=29.049 | smoothed_loss_disc=4.065
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 50)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 50)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_50e_900s_best_epoch.pth' (epoch 50 and step 900)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_50e_900s.pth' (epoch 50 and step 900)
#  83% 15/18 [00:09<00:01,  1.62it/s]Backup Complete: 2 new, 4 updated, 1 deleted.
#  94% 17/18 [00:10<00:00,  1.61it/s]Files are up to date.
# New best epoch 51 with smoothed loss_g 28.993 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=51 | step=918 | time=16:25:42 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.993 | smoothed_loss_disc=4.063
# Backup Complete: 2 new, 4 updated, 1 deleted.
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_51e_918s_best_epoch.pth' (epoch 51 and step 918)
#   6% 1/18 [00:00<00:09,  1.71it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  17% 3/18 [00:01<00:08,  1.67it/s]Files are up to date.
# New best epoch 52 with smoothed loss_g 28.938 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=52 | step=936 | time=16:25:53 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.938 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_52e_936s_best_epoch.pth' (epoch 52 and step 936)
#  28% 5/18 [00:03<00:07,  1.65it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  39% 7/18 [00:04<00:06,  1.62it/s]Files are up to date.
# New best epoch 53 with smoothed loss_g 28.884 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=53 | step=954 | time=16:26:05 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.884 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_53e_954s_best_epoch.pth' (epoch 53 and step 954)
# New best epoch 54 with smoothed loss_g 28.830 and loss_d 4.065
# zwanglos-v3-meta_glasses | epoch=54 | step=972 | time=16:26:16 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.830 | smoothed_loss_disc=4.065
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_54e_972s_best_epoch.pth' (epoch 54 and step 972)
#  83% 15/18 [00:09<00:01,  1.65it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_53e_954s_best_epoch.pth'
# An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_53e_954s_best_epoch.pth'
#  89% 16/18 [00:09<00:01,  1.63it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  94% 17/18 [00:10<00:00,  1.63it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# New best epoch 55 with smoothed loss_g 28.778 and loss_d 4.066
# zwanglos-v3-meta_glasses | epoch=55 | step=990 | time=16:26:28 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.778 | smoothed_loss_disc=4.066
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_55e_990s_best_epoch.pth' (epoch 55 and step 990)
#   0% 0/18 [00:00<?, ?it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/drive/MyDrive/ApplioBackup/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_54e_972s_best_epoch.pth'
# Backup Complete: 0 new, 1 updated, 1 deleted.
# An error occurred during backup: dictionary update sequence element #4811 has length 1; 2 is required
#  17% 3/18 [00:01<00:09,  1.60it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  28% 5/18 [00:03<00:08,  1.60it/s]Files are up to date.
# New best epoch 56 with smoothed loss_g 28.726 and loss_d 4.067
# zwanglos-v3-meta_glasses | epoch=56 | step=1008 | time=16:26:40 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.726 | smoothed_loss_disc=4.067
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_56e_1008s_best_epoch.pth' (epoch 56 and step 1008)
#  67% 12/18 [00:07<00:03,  1.63it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# New best epoch 57 with smoothed loss_g 28.674 and loss_d 4.067
# zwanglos-v3-meta_glasses | epoch=57 | step=1026 | time=16:26:52 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.674 | smoothed_loss_disc=4.067
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_57e_1026s_best_epoch.pth' (epoch 57 and step 1026)
#   6% 1/18 [00:00<00:10,  1.62it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#  28% 5/18 [00:03<00:07,  1.63it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  39% 7/18 [00:04<00:06,  1.63it/s]Files are up to date.
# New best epoch 58 with smoothed loss_g 28.623 and loss_d 4.066
# zwanglos-v3-meta_glasses | epoch=58 | step=1044 | time=16:27:03 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.623 | smoothed_loss_disc=4.066
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_58e_1044s_best_epoch.pth' (epoch 58 and step 1044)
#  89% 16/18 [00:09<00:01,  1.65it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# New best epoch 59 with smoothed loss_g 28.573 and loss_d 4.064
# zwanglos-v3-meta_glasses | epoch=59 | step=1062 | time=16:27:15 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.573 | smoothed_loss_disc=4.064
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_59e_1062s_best_epoch.pth' (epoch 59 and step 1062)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#  17% 3/18 [00:01<00:09,  1.67it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  28% 5/18 [00:03<00:07,  1.67it/s]Files are up to date.
# New best epoch 60 with smoothed loss_g 28.524 and loss_d 4.063
# zwanglos-v3-meta_glasses | epoch=60 | step=1080 | time=16:27:27 | training_speed=0:00:12 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.524 | smoothed_loss_disc=4.063
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 60)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 60)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_60e_1080s_best_epoch.pth' (epoch 60 and step 1080)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_60e_1080s.pth' (epoch 60 and step 1080)
# New best epoch 61 with smoothed loss_g 28.475 and loss_d 4.060
# zwanglos-v3-meta_glasses | epoch=61 | step=1098 | time=16:27:42 | training_speed=0:00:11 | lowest_value=24.771 (epoch 49 and step 880) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.475 | smoothed_loss_disc=4.060
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_61e_1098s_best_epoch.pth' (epoch 61 and step 1098)
#  22% 4/18 [00:02<00:08,  1.65it/s]Backup Complete: 2 new, 4 updated, 2 deleted.
#  39% 7/18 [00:04<00:06,  1.64it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  56% 10/18 [00:06<00:04,  1.64it/s]Files are up to date.
# New best epoch 62 with smoothed loss_g 28.426 and loss_d 4.060
# zwanglos-v3-meta_glasses | epoch=62 | step=1116 | time=16:27:53 | training_speed=0:00:11 | lowest_value=24.697 (epoch 62 and step 1106) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.426 | smoothed_loss_disc=4.060
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_62e_1116s_best_epoch.pth' (epoch 62 and step 1116)
#  89% 16/18 [00:10<00:01,  1.60it/s]Backup Complete: 8130 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 1 deleted.
# New best epoch 63 with smoothed loss_g 28.377 and loss_d 4.060
# zwanglos-v3-meta_glasses | epoch=63 | step=1134 | time=16:28:05 | training_speed=0:00:11 | lowest_value=24.697 (epoch 62 and step 1106) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.377 | smoothed_loss_disc=4.060
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_63e_1134s_best_epoch.pth' (epoch 63 and step 1134)
#   6% 1/18 [00:00<00:10,  1.66it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  17% 3/18 [00:01<00:09,  1.66it/s]Files are up to date.
#  44% 8/18 [00:04<00:06,  1.62it/s]Backup Complete: 1 new, 4 updated, 0 deleted.
#  56% 10/18 [00:06<00:05,  1.59it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  67% 12/18 [00:07<00:03,  1.62it/s]Files are up to date.
# New best epoch 64 with smoothed loss_g 28.330 and loss_d 4.058
# ...
#  33% 6/18 [00:03<00:07,  1.68it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  39% 7/18 [00:04<00:06,  1.68it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  44% 8/18 [00:05<00:06,  1.46it/s]Files are up to date.
#  50% 9/18 [00:05<00:05,  1.51it/s]Files are up to date.
# New best epoch 160 with smoothed loss_g 25.291 and loss_d 4.007
# zwanglos-v3-meta_glasses | epoch=160 | step=2880 | time=16:47:18 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 41 | smoothed_loss_gen=25.291 | smoothed_loss_disc=4.007
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 160)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 160)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_160e_2880s_best_epoch.pth' (epoch 160 and step 2880)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_160e_2880s.pth' (epoch 160 and step 2880)
# New best epoch 161 with smoothed loss_g 25.269 and loss_d 4.006
# zwanglos-v3-meta_glasses | epoch=161 | step=2898 | time=16:47:32 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 40 | smoothed_loss_gen=25.269 | smoothed_loss_disc=4.006
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_161e_2898s_best_epoch.pth' (epoch 161 and step 2898)
#  17% 3/18 [00:01<00:09,  1.58it/s]Backup Complete: 1 new, 4 updated, 1 deleted.
#  28% 5/18 [00:03<00:08,  1.59it/s]Backup Complete: 1 new, 4 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  39% 7/18 [00:04<00:06,  1.63it/s]Files are up to date.
#  44% 8/18 [00:04<00:06,  1.62it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  50% 9/18 [00:05<00:05,  1.61it/s]Files are up to date.
# New best epoch 162 with smoothed loss_g 25.248 and loss_d 4.007
# zwanglos-v3-meta_glasses | epoch=162 | step=2916 | time=16:47:43 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 39 | smoothed_loss_gen=25.248 | smoothed_loss_disc=4.007
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_162e_2916s_best_epoch.pth' (epoch 162 and step 2916)
#  83% 15/18 [00:09<00:01,  1.60it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  94% 17/18 [00:10<00:00,  1.63it/s]Files are up to date.
# New best epoch 163 with smoothed loss_g 25.227 and loss_d 4.005
# zwanglos-v3-meta_glasses | epoch=163 | step=2934 | time=16:47:55 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 38 | smoothed_loss_gen=25.227 | smoothed_loss_disc=4.005
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_163e_2934s_best_epoch.pth' (epoch 163 and step 2934)
# New best epoch 164 with smoothed loss_g 25.207 and loss_d 4.002
# zwanglos-v3-meta_glasses | epoch=164 | step=2952 | time=16:48:06 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 37 | smoothed_loss_gen=25.207 | smoothed_loss_disc=4.002
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_164e_2952s_best_epoch.pth' (epoch 164 and step 2952)
#  33% 6/18 [00:03<00:07,  1.54it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  44% 8/18 [00:05<00:06,  1.58it/s]Files are up to date.
# Files are up to date.
# New best epoch 165 with smoothed loss_g 25.186 and loss_d 4.001
# zwanglos-v3-meta_glasses | epoch=165 | step=2970 | time=16:48:17 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 36 | smoothed_loss_gen=25.186 | smoothed_loss_disc=4.001
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_165e_2970s_best_epoch.pth' (epoch 165 and step 2970)
#  89% 16/18 [00:09<00:01,  1.48it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 1 deleted.
# New best epoch 166 with smoothed loss_g 25.166 and loss_d 4.000
# zwanglos-v3-meta_glasses | epoch=166 | step=2988 | time=16:48:29 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 35 | smoothed_loss_gen=25.166 | smoothed_loss_disc=4.000
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_166e_2988s_best_epoch.pth' (epoch 166 and step 2988)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
#  11% 2/18 [00:01<00:09,  1.62it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  22% 4/18 [00:02<00:08,  1.64it/s]Files are up to date.
# Files are up to date.
# New best epoch 167 with smoothed loss_g 25.146 and loss_d 3.998
# zwanglos-v3-meta_glasses | epoch=167 | step=3006 | time=16:48:40 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 34 | smoothed_loss_gen=25.146 | smoothed_loss_disc=3.998
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_167e_3006s_best_epoch.pth' (epoch 167 and step 3006)
#   0% 0/18 [00:00<?, ?it/s]Using HiFi-GAN vocoder
#  22% 4/18 [00:02<00:09,  1.54it/s]Converting audio 'assets/audios/Oimara_-_Wackelkontakt_vocals.mp3'...
#  50% 9/18 [00:07<00:09,  1.00s/it]Conversion completed at 'assets/audios/Oimara_-_Wackelkontakt_vocals_output.wav' in 4.29 seconds.
# Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  61% 11/18 [00:08<00:05,  1.25it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
#  67% 12/18 [00:08<00:04,  1.34it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
#  72% 13/18 [00:09<00:03,  1.42it/s]Files are up to date.
# Files are up to date.
# New best epoch 168 with smoothed loss_g 25.127 and loss_d 3.995
# zwanglos-v3-meta_glasses | epoch=168 | step=3024 | time=16:48:54 | training_speed=0:00:13 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 33 | smoothed_loss_gen=25.127 | smoothed_loss_disc=3.995
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_168e_3024s_best_epoch.pth' (epoch 168 and step 3024)
# New best epoch 169 with smoothed loss_g 25.107 and loss_d 3.995
# zwanglos-v3-meta_glasses | epoch=169 | step=3042 | time=16:49:05 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 32 | smoothed_loss_gen=25.107 | smoothed_loss_disc=3.995
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_169e_3042s_best_epoch.pth' (epoch 169 and step 3042)
#  11% 2/18 [00:01<00:12,  1.31it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  17% 3/18 [00:02<00:10,  1.45it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  28% 5/18 [00:03<00:08,  1.61it/s]Files are up to date.
# Files are up to date.
# New best epoch 170 with smoothed loss_g 25.088 and loss_d 3.994
# zwanglos-v3-meta_glasses | epoch=170 | step=3060 | time=16:49:17 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 31 | smoothed_loss_gen=25.088 | smoothed_loss_disc=3.994
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 170)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 170)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_170e_3060s_best_epoch.pth' (epoch 170 and step 3060)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_170e_3060s.pth' (epoch 170 and step 3060)
#  89% 16/18 [00:10<00:01,  1.54it/s]Backup Complete: 2 new, 4 updated, 1 deleted.
# Backup Complete: 2 new, 4 updated, 0 deleted.
# New best epoch 171 with smoothed loss_g 25.070 and loss_d 3.993
# zwanglos-v3-meta_glasses | epoch=171 | step=3078 | time=16:49:34 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 30 | smoothed_loss_gen=25.070 | smoothed_loss_disc=3.993
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_171e_3078s_best_epoch.pth' (epoch 171 and step 3078)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#   6% 1/18 [00:00<00:10,  1.65it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  11% 2/18 [00:01<00:09,  1.66it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 3/18 [00:01<00:08,  1.68it/s]Files are up to date.
#  22% 4/18 [00:02<00:08,  1.66it/s]Files are up to date.
# New best epoch 172 with smoothed loss_g 25.051 and loss_d 3.993
# zwanglos-v3-meta_glasses | epoch=172 | step=3096 | time=16:49:45 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 29 | smoothed_loss_gen=25.051 | smoothed_loss_disc=3.993
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_172e_3096s_best_epoch.pth' (epoch 172 and step 3096)
#  61% 11/18 [00:06<00:04,  1.61it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  67% 12/18 [00:07<00:03,  1.63it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
#  78% 14/18 [00:08<00:02,  1.62it/s]Files are up to date.
# Files are up to date.
# New best epoch 173 with smoothed loss_g 25.033 and loss_d 3.991
# zwanglos-v3-meta_glasses | epoch=173 | step=3114 | time=16:49:57 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 28 | smoothed_loss_gen=25.033 | smoothed_loss_disc=3.991
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_173e_3114s_best_epoch.pth' (epoch 173 and step 3114)
# New best epoch 174 with smoothed loss_g 25.015 and loss_d 3.992
# zwanglos-v3-meta_glasses | epoch=174 | step=3132 | time=16:50:09 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 27 | smoothed_loss_gen=25.015 | smoothed_loss_disc=3.992
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_174e_3132s_best_epoch.pth' (epoch 174 and step 3132)
#  83% 15/18 [00:08<00:01,  1.67it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  89% 16/18 [00:09<00:01,  1.64it/s]Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# New best epoch 175 with smoothed loss_g 24.997 and loss_d 3.992
# zwanglos-v3-meta_glasses | epoch=175 | step=3150 | time=16:50:20 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 26 | smoothed_loss_gen=24.997 | smoothed_loss_disc=3.992
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_175e_3150s_best_epoch.pth' (epoch 175 and step 3150)
# New best epoch 176 with smoothed loss_g 24.979 and loss_d 3.990
# zwanglos-v3-meta_glasses | epoch=176 | step=3168 | time=16:50:32 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 25 | smoothed_loss_gen=24.979 | smoothed_loss_disc=3.990
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_176e_3168s_best_epoch.pth' (epoch 176 and step 3168)
# New best epoch 177 with smoothed loss_g 24.962 and loss_d 3.988
# zwanglos-v3-meta_glasses | epoch=177 | step=3186 | time=16:50:44 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 24 | smoothed_loss_gen=24.962 | smoothed_loss_disc=3.988
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_177e_3186s_best_epoch.pth' (epoch 177 and step 3186)
#  72% 13/18 [00:08<00:02,  1.68it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_176e_3168s_best_epoch.pth'
#  78% 14/18 [00:08<00:02,  1.67it/s]An error occurred during backup: [Errno 2] No such file or directory: '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_176e_3168s_best_epoch.pth'
#  89% 16/18 [00:09<00:01,  1.65it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 178 with smoothed loss_g 24.945 and loss_d 3.986
# zwanglos-v3-meta_glasses | epoch=178 | step=3204 | time=16:50:55 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 23 | smoothed_loss_gen=24.945 | smoothed_loss_disc=3.986
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_178e_3204s_best_epoch.pth' (epoch 178 and step 3204)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#  11% 2/18 [00:01<00:10,  1.57it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 3/18 [00:01<00:09,  1.60it/s]Files are up to date.
# New best epoch 179 with smoothed loss_g 24.928 and loss_d 3.986
# zwanglos-v3-meta_glasses | epoch=179 | step=3222 | time=16:51:07 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 22 | smoothed_loss_gen=24.928 | smoothed_loss_disc=3.986
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_179e_3222s_best_epoch.pth' (epoch 179 and step 3222)
#  39% 7/18 [00:04<00:06,  1.65it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
#  44% 8/18 [00:04<00:06,  1.65it/s]Files are up to date.
# New best epoch 180 with smoothed loss_g 24.911 and loss_d 3.984
# zwanglos-v3-meta_glasses | epoch=180 | step=3240 | time=16:51:19 | training_speed=0:00:11 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 21 | smoothed_loss_gen=24.911 | smoothed_loss_disc=3.984
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/G_2333333.pth' (epoch 180)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/D_2333333.pth' (epoch 180)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_180e_3240s_best_epoch.pth' (epoch 180 and step 3240)
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_180e_3240s.pth' (epoch 180 and step 3240)
#  33% 6/18 [00:03<00:08,  1.44it/s]Converting audio 'assets/audios/1_Flussiges_Gluck_-_Original_Vocals.mp3'...
# New best epoch 181 with smoothed loss_g 24.894 and loss_d 3.983
# zwanglos-v3-meta_glasses | epoch=181 | step=3258 | time=16:51:37 | training_speed=0:00:13 | lowest_value=23.641 (epoch 153 and step 2744) | Number of epochs remaining for overtraining: g/total: 50 d/total: 20 | smoothed_loss_gen=24.894 | smoothed_loss_disc=3.983
# Conversion completed at 'assets/audios/1_Flussiges_Gluck_-_Original_Vocals_output.wav' in 8.96 seconds.
# Saved model '/content/Applio/logs/zwanglos-v3-meta_glasses/zwanglos-v3-meta_glasses_181e_3258s_best_epoch.pth' (epoch 181 and step 3258)
#   0% 0/18 [00:00<?, ?it/s]Backup Complete: 2 new, 4 updated, 2 deleted.
#  17% 3/18 [00:01<00:09,  1.62it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 2 new, 4 updated, 0 deleted.
#  50% 9/18 [00:05<00:05,  1.66it/s]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  61% 11/18 [00:06<00:04,  1.65it/s]Files are up to date.
# Files are up to date.
#  89% 16/18 [00:09<00:01,  1.67it/s]

# %% [markdown]
# ### **Extra**
# Enjoy extra options that can make it easier for you to use Applio

# %%
# !ln -s "/content/drive/MyDrive/voicemodel-source_rode_nt1_wav" "assets/datasets/voicemodel-source_rode_nt1_wav"
# !ln -s "/content/drive/MyDrive/voicemodel-source_metaglasses_wav" "assets/datasets/voicemodel-source_metaglasses_wav"
epochs = 150

# %%
# @title Mount Drive
# @markdown Mount the files from Google Drive to the Colab.
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# @title Auto Backup
# @markdown When running it, it will be activated or deactivated previously to start up together with Applio.
import os
import shutil
import time

LOGS_FOLDER = "/content/Applio/logs/"
GOOGLE_DRIVE_PATH = "/content/drive/MyDrive/ApplioBackup"

if "autobackups" not in globals():
    autobackups = False

cooldown = 15  # @param {type:"slider", min:0, max:100, step:0}
def backup_files():
    print("\nStarting backup loop...")
    last_backup_timestamps_path = os.path.join(
        LOGS_FOLDER, "last_backup_timestamps.txt"
    )
    fully_updated = False

    while True:
        try:
            updated_files = 0
            deleted_files = 0
            new_files = 0
            last_backup_timestamps = {}

            try:
                with open(last_backup_timestamps_path, "r") as f:
                    last_backup_timestamps = dict(line.strip().split(":") for line in f)
            except FileNotFoundError:
                pass

            for root, dirs, files in os.walk(LOGS_FOLDER):
                # Excluding "zips" and "mute" directories
                if "zips" in dirs:
                    dirs.remove("zips")
                if "mute" in dirs:
                    dirs.remove("mute")

                for filename in files:
                    if filename != "last_backup_timestamps.txt":
                        filepath = os.path.join(root, filename)
                        if os.path.isfile(filepath):
                            backup_filepath = os.path.join(
                                GOOGLE_DRIVE_PATH,
                                os.path.relpath(filepath, LOGS_FOLDER),
                            )
                            backup_folderpath = os.path.dirname(backup_filepath)
                            if not os.path.exists(backup_folderpath):
                                os.makedirs(backup_folderpath)
                            last_backup_timestamp = last_backup_timestamps.get(filepath)
                            current_timestamp = os.path.getmtime(filepath)
                            if (
                                last_backup_timestamp is None
                                or float(last_backup_timestamp) < current_timestamp
                            ):
                                shutil.copy2(filepath, backup_filepath)
                                last_backup_timestamps[filepath] = str(current_timestamp)
                                if last_backup_timestamp is None:
                                    new_files += 1
                                else:
                                    updated_files += 1


            for filepath in list(last_backup_timestamps.keys()):
                if not os.path.exists(filepath):
                    backup_filepath = os.path.join(
                        GOOGLE_DRIVE_PATH, os.path.relpath(filepath, LOGS_FOLDER)
                    )
                    if os.path.exists(backup_filepath):
                        os.remove(backup_filepath)
                        deleted_files += 1
                    del last_backup_timestamps[filepath]


            if updated_files > 0 or deleted_files > 0 or new_files > 0:
                print(f"Backup Complete: {new_files} new, {updated_files} updated, {deleted_files} deleted.")
                fully_updated = False
            elif not fully_updated:
                print("Files are up to date.")
                fully_updated = True

            with open(last_backup_timestamps_path, "w") as f:
                for filepath, timestamp in last_backup_timestamps.items():
                    f.write(f"{filepath}:{timestamp}\n")

            time.sleep(cooldown if fully_updated else 0.1)


        except Exception as error:
            print(f"An error occurred during backup: {error}")


if autobackups:
    autobackups = False
    print("Autobackup Disabled")
else:
    autobackups = True
    print("Autobackup Enabled")
# Out:
# Autobackup Enabled

# %%
# @title Load a Backup
import os
import shutil

# @markdown Put the exact name you put as your Model Name in Applio.
modelname = "zwanglos-v2-rode_nt1"  # @param {type:"string"}
source_path = "/content/drive/MyDrive/ApplioBackup/" + modelname
destination_path = "/content/Applio/logs/" + modelname
backup_timestamps_file = "last_backup_timestamps.txt"
if not os.path.exists(source_path):
    print(
        "The model folder does not exist. Please verify the name is correct or check your Google Drive."
    )
else:
    time_ = os.path.join("/content/drive/MyDrive/ApplioBackup/", backup_timestamps_file)
    time__ = os.path.join("/content/Applio/logs/", backup_timestamps_file)
    if os.path.exists(time_):
        shutil.copy(time_, time__)
    shutil.copytree(source_path, destination_path)
    print("Model backup loaded successfully.")
# Out:
# Model backup loaded successfully.
