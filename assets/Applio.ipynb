# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsippel/colab/blob/main/assets/Applio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Applio**
# A simple, high-quality voice conversion tool focused on ease of use and performance.
#
# [Support](https://discord.gg/urxFjYmYYh) — [GitHub](https://github.com/IAHispano/Applio) — [Terms of Use](https://github.com/IAHispano/Applio/blob/main/TERMS_OF_USE.md)
#
# <br>
#
# ---
#
# <br>
#
# #### **Acknowledgments**
#
# To all external collaborators for their special help in the following areas: Hina (Encryption method), Poopmaster (Extra section), Shirou (UV installer)
#
# #### **Disclaimer**
# By using Applio, you agree to comply with ethical and legal standards, respect intellectual property and privacy rights, avoid harmful or prohibited uses, and accept full responsibility for any outcomes, while Applio disclaims liability and reserves the right to amend these terms.

# %%
# @title **Install Applio**
import sys
from IPython.display import clear_output
import codecs
import os

encoded_url = "uggcf://tvguho.pbz/VNUvfcnab/Nccyvb/"
decoded_url = codecs.decode(encoded_url, "rot_13")

repo_name_encoded = "Nccyvb"
repo_name = codecs.decode(repo_name_encoded, "rot_13")

# !pip install -q uv

# !git clone --depth 1 {decoded_url} --branch 3.2.9 --single-branch
# %cd {repo_name}
clear_output()

print("Installing requirements...")
# !uv pip install torch==2.7.1 torchvision torchaudio==2.7.1 \
  --index-url https://download.pytorch.org/whl/cu128 \
  -q
# !uv pip install -r requirements.txt -q
# !uv pip install pyngrok -q

clear_output()
print("✅ Finished installing requirements!")
# Out:
# ✅ Finished installing requirements!

# %%
# @title **Start Applio**
# @markdown  ### Choose a sharing method:

import codecs
import threading
import urllib.request
import time
import ipywidgets as widgets
from IPython.display import display
import os
from pyngrok import ngrok
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

method = "gradio"  # @param ["gradio", "localtunnel", "ngrok"]
ngrok_token = "If you selected the 'ngrok' method, obtain your auth token here: https://dashboard.ngrok.com/get-started/your-authtoken" # @param {type:"string"}
tensorboard = False #@param {type: "boolean"}

def start_gradio():
    # !python app.py --listen --share

def start_localtunnel():
    # !npm install -g localtunnel &>/dev/null
    with open('url.txt', 'w') as file:
        file.write('')
    get_ipython().system_raw('lt --port 6969 >> url.txt 2>&1 &')
    time.sleep(2)
    endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n")

    with open('url.txt', 'r') as file:
        tunnel_url = file.read()
        tunnel_url = tunnel_url.replace("your url is: ", "")

    print(f"Share Link: \033[0m\033[93m{tunnel_url}\033[0m", end="\033[0m\n")

    password_endpoint_widget = widgets.Text(
    value=endpoint_ip,
    description='Password IP:',
    disabled=True
    )
    display(password_endpoint_widget)
    # !python app.py --listen


def start_ngrok():
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: \033[0m\033[93m{tunnel.public_url}\033[0m", end="\033[0m\n")
        # !python app.py --listen
    except Exception as e:
        print(f"Error starting ngrok: {e}")

def start_applio():
    if method == 'gradio':
        start_gradio()
    elif method == 'localtunnel':
        start_localtunnel()
    elif method == 'ngrok':
        start_ngrok()

if tensorboard:
    # %load_ext tensorboard
    # %reload_ext tensorboard
    # %tensorboard --logdir logs --bind_all

if "autobackups" not in globals():
    autobackups = False

if autobackups:
    thread = threading.Thread(target=backup_files)
    thread.start()

thread_applio = threading.Thread(target=start_applio)
thread_applio.start()


while True:
    time.sleep(5)
# Out:
# An error occurred connecting to Discord: Could not find Discord installed and running on this machine.
# * Running on local URL:  http://127.0.0.1:6969
# * Running on public URL: https://ce9c383f916d1a89f5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751113860.361358   36669 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751113860.370209   36669 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/content/Applio/rvc/train/train.py", line 86, in <module>
#     with open(config_save_path, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Applio/logs/my-project/config.json'
# An error occurred extracting the index: [Errno 2] No such file or directory: '/content/Applio/logs/my-project/extracted'
# If you are running this code in a virtual environment, make sure you have enough GPU available to generate the Index file.
# Starting pitch extraction with 2 cores on cuda:0 using rmvpe...
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
# 0it [00:00, ?it/s]
# Pitch extraction completed in 8.09 seconds.
# Starting embedding extraction with 2 cores on cuda:0...
# 0it [00:00, ?it/s]
# Embedding extraction completed in 7.02 seconds.
# Traceback (most recent call last):
#   File "/content/Applio/rvc/train/extract/extract.py", line 248, in <module>
#     generate_filelist(exp_dir, sample_rate, include_mutes)
#   File "/content/Applio/rvc/train/extract/preparing_files.py", line 26, in generate_filelist
#     gt_wavs_files = set(name.split(".")[0] for name in os.listdir(gt_wavs_dir))
#                                                        ^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Applio/logs/my-project/sliced_audios'
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
# Starting preprocess with 2 processes...
# 100% 18/18 [00:11<00:00,  1.56it/s]
# Preprocess completed in 11.59 seconds on 00:36:06 seconds of audio.
# Backup Complete: 0 new, 887 updated, 0 deleted.
# Starting pitch extraction with 2 cores on cuda:0 using rmvpe...
# 100% 781/781 [00:00<00:00, 3723.43it/s]
# An error occurred during backup: [Errno 1] Operation not permitted: '/content/drive/MyDrive/ApplioBackup/zwanglos-v2-rode_nt1/sliced_audios_16k/0_17_9.wav'
# Pitch extraction completed in 10.55 seconds.
# Starting embedding extraction with 2 cores on cuda:0...
# 100% 781/781 [00:00<00:00, 3849.01it/s]
# Embedding extraction completed in 10.35 seconds.
# Backup Complete: 0 new, 676 updated, 0 deleted.
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Files are up to date.
# Backup Complete: 0 new, 676 updated, 0 deleted.
# An error occurred during backup: [Errno 1] Operation not permitted: '/content/drive/MyDrive/ApplioBackup/zwanglos-v2-rode_nt1/sliced_audios/0_5_3.wav'
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Backup Complete: 0 new, 1557 updated, 0 deleted.
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Files are up to date.
# Backup Complete: 0 new, 7 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# Backup Complete: 0 new, 1563 updated, 0 deleted.
# Backup Complete: 0 new, 1521 updated, 0 deleted.
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Backup Complete: 0 new, 43 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114108.435340   37843 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114108.441509   37843 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Removing files from the prior training attempt...
# Cleanup done!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114116.855756   37887 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114116.862835   37887 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Backup Complete: 0 new, 1 updated, 1 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Using HiFi-GAN vocoder
# Starting training...
# Loaded pretrained (G) 'rvc/models/pretraineds/hifi-gan/f0G40k.pth'
# Loaded pretrained (D) 'rvc/models/pretraineds/hifi-gan/f0D40k.pth'
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114128.934007   37945 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114128.939862   37945 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114135.340035   37985 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114135.346160   37985 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114143.319801   38026 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114143.330117   38026 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114150.473618   38071 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114150.481055   38071 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# zwanglos-v2-rode_nt1 | epoch=1 | step=54 | time=12:39:05 | training_speed=0:02:58 | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=0.000 | smoothed_loss_disc=0.000
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   2% 1/54 [00:02<02:24,  2.73s/it]Files are up to date.
# Files are up to date.
#  15% 8/54 [00:20<01:58,  2.57s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
#  78% 42/54 [01:47<00:30,  2.55s/it]An error occurred during backup: dictionary update sequence element #1829 has length 1; 2 is required
# An error occurred during backup: dictionary update sequence element #1829 has length 1; 2 is required
# New best epoch 2 with smoothed loss_g 28.436 and loss_d 4.300
# zwanglos-v2-rode_nt1 | epoch=2 | step=108 | time=12:41:29 | training_speed=0:02:23 | lowest_value=28.436 (epoch 2 and step 85) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.436 | smoothed_loss_disc=4.300
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_2e_108s_best_epoch.pth' (epoch 2 and step 108)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 0 deleted.
# Saved index file '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1.index'
#   4% 2/54 [00:05<02:18,  2.67s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
#  17% 9/54 [00:22<01:52,  2.49s/it]Backup Complete: 2 new, 0 updated, 0 deleted.
#  19% 10/54 [00:25<01:53,  2.58s/it]Files are up to date.
#  28% 15/54 [00:37<01:36,  2.48s/it]Backup Complete: 2 new, 0 updated, 0 deleted.
# Backup Complete: 2 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 2 new, 0 updated, 0 deleted.
#  33% 18/54 [00:45<01:28,  2.46s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  41% 22/54 [00:55<01:22,  2.59s/it]Backup Complete: 3310 new, 0 updated, 0 deleted.
#  43% 23/54 [00:58<01:19,  2.56s/it]Backup Complete: 2 new, 0 updated, 0 deleted.
# Files are up to date.
#  54% 29/54 [01:12<00:59,  2.39s/it]Using HiFi-GAN vocoder
#  59% 32/54 [01:19<00:53,  2.45s/it]Converting audio 'assets/audios/ohrwurm-beat-15s_v43_KNALLERRAKETE_Vocals.wav'...
#  74% 40/54 [01:47<00:53,  3.80s/it]Conversion completed at 'assets/audios/ohrwurm-beat-15s_v43_KNALLERRAKETE_Vocals_output.wav' in 28.12 seconds.
#  81% 44/54 [01:57<00:27,  2.74s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  83% 45/54 [01:59<00:23,  2.63s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  85% 46/54 [02:02<00:20,  2.58s/it]Files are up to date.
#  87% 47/54 [02:04<00:18,  2.62s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# New best epoch 3 with smoothed loss_g 28.425 and loss_d 4.299
# zwanglos-v2-rode_nt1 | epoch=3 | step=162 | time=12:43:53 | training_speed=0:02:23 | lowest_value=27.578 (epoch 3 and step 135) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.425 | smoothed_loss_disc=4.299
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_3e_162s_best_epoch.pth' (epoch 3 and step 162)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#   2% 1/54 [00:02<02:12,  2.51s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   4% 2/54 [00:05<02:10,  2.50s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
#   7% 4/54 [00:10<02:06,  2.52s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Converting audio 'assets/audios/SHORTENED-test.wav'...
#   9% 5/54 [00:12<02:03,  2.52s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
#  11% 6/54 [00:15<02:07,  2.65s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 4.36 seconds.
# Files are up to date.
#  13% 7/54 [00:18<02:13,  2.84s/it]Files are up to date.
# Files are up to date.
#  33% 18/54 [00:45<01:29,  2.48s/it]Backup Complete: 3497 new, 0 updated, 0 deleted.
#  35% 19/54 [00:48<01:27,  2.49s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
#  70% 38/54 [01:34<00:38,  2.43s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 4 with smoothed loss_g 28.414 and loss_d 4.300
# zwanglos-v2-rode_nt1 | epoch=4 | step=216 | time=12:46:06 | training_speed=0:02:13 | lowest_value=27.578 (epoch 3 and step 135) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.414 | smoothed_loss_disc=4.300
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_4e_216s_best_epoch.pth' (epoch 4 and step 216)
#   2% 1/54 [00:02<02:38,  3.00s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   4% 2/54 [00:05<02:20,  2.71s/it]Files are up to date.
# Files are up to date.
#  57% 31/54 [01:15<00:55,  2.39s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 5 with smoothed loss_g 28.399 and loss_d 4.298
# zwanglos-v2-rode_nt1 | epoch=5 | step=270 | time=12:48:18 | training_speed=0:02:11 | lowest_value=27.26 (epoch 5 and step 241) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.399 | smoothed_loss_disc=4.298
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_5e_270s_best_epoch.pth' (epoch 5 and step 270)
#   2% 1/54 [00:02<02:07,  2.41s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   4% 2/54 [00:04<02:06,  2.43s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
#  56% 30/54 [01:12<00:57,  2.41s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 6 with smoothed loss_g 28.377 and loss_d 4.297
# zwanglos-v2-rode_nt1 | epoch=6 | step=324 | time=12:50:29 | training_speed=0:02:11 | lowest_value=26.702 (epoch 6 and step 311) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.377 | smoothed_loss_disc=4.297
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_6e_324s_best_epoch.pth' (epoch 6 and step 324)
#   6% 3/54 [00:06<01:58,  2.32s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   7% 4/54 [00:09<01:58,  2.36s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
#   9% 5/54 [00:11<01:55,  2.36s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  46% 25/54 [01:00<01:10,  2.43s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
#  94% 51/54 [02:03<00:07,  2.46s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  96% 52/54 [02:06<00:05,  2.63s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 3.59 seconds.
# New best epoch 7 with smoothed loss_g 28.355 and loss_d 4.298
# zwanglos-v2-rode_nt1 | epoch=7 | step=378 | time=12:52:41 | training_speed=0:02:12 | lowest_value=26.702 (epoch 6 and step 311) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.355 | smoothed_loss_disc=4.298
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_7e_378s_best_epoch.pth' (epoch 7 and step 378)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   2% 1/54 [00:02<02:12,  2.51s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
#   4% 2/54 [00:04<02:08,  2.46s/it]Files are up to date.
# Files are up to date.
#  30% 16/54 [00:38<01:31,  2.42s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 8 with smoothed loss_g 28.334 and loss_d 4.295
# zwanglos-v2-rode_nt1 | epoch=8 | step=432 | time=12:54:53 | training_speed=0:02:11 | lowest_value=26.702 (epoch 6 and step 311) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.334 | smoothed_loss_disc=4.295
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_8e_432s_best_epoch.pth' (epoch 8 and step 432)
#   4% 2/54 [00:04<01:59,  2.29s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 3/54 [00:06<01:58,  2.32s/it]Files are up to date.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.Files are up to date.
#
#  22% 12/54 [00:28<01:41,  2.42s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  24% 13/54 [00:31<01:41,  2.48s/it]Files are up to date.
# Files are up to date.
# New best epoch 9 with smoothed loss_g 28.313 and loss_d 4.293
# zwanglos-v2-rode_nt1 | epoch=9 | step=486 | time=12:57:04 | training_speed=0:02:11 | lowest_value=26.702 (epoch 6 and step 311) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.313 | smoothed_loss_disc=4.293
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_9e_486s_best_epoch.pth' (epoch 9 and step 486)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   2% 1/54 [00:02<02:15,  2.55s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#   4% 2/54 [00:05<02:10,  2.51s/it]
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  15% 8/54 [00:19<01:53,  2.46s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# Converting audio 'assets/audios/SHORTENED-test.wav'...
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 3.71 seconds.
# New best epoch 10 with smoothed loss_g 28.283 and loss_d 4.288
# zwanglos-v2-rode_nt1 | epoch=10 | step=540 | time=12:59:46 | training_speed=0:02:41 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.283 | smoothed_loss_disc=4.288
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/G_2333333.pth' (epoch 10)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/D_2333333.pth' (epoch 10)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_10e_540s_best_epoch.pth' (epoch 10 and step 540)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_10e_540s.pth' (epoch 10 and step 540)
#  22% 12/54 [00:30<01:47,  2.56s/it]Backup Complete: 2 new, 1 updated, 1 deleted.
# Backup Complete: 2 new, 1 updated, 0 deleted.
# Backup Complete: 2 new, 1 updated, 0 deleted.
#  98% 53/54 [02:11<00:02,  2.47s/it]Backup Complete: 3 new, 1 updated, 0 deleted.
# Backup Complete: 3 new, 1 updated, 0 deleted.
# Backup Complete: 3 new, 1 updated, 0 deleted.
# New best epoch 11 with smoothed loss_g 28.253 and loss_d 4.291
# zwanglos-v2-rode_nt1 | epoch=11 | step=594 | time=13:02:35 | training_speed=0:02:16 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.253 | smoothed_loss_disc=4.291
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_11e_594s_best_epoch.pth' (epoch 11 and step 594)
#   6% 3/54 [00:07<01:59,  2.34s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#  11% 6/54 [00:15<02:02,  2.56s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  13% 7/54 [00:17<01:59,  2.54s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  20% 11/54 [00:27<01:48,  2.51s/it]Backup Complete: 2 new, 2 updated, 0 deleted.Backup Complete: 2 new, 2 updated, 0 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
#
#  30% 16/54 [00:40<01:38,  2.59s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  33% 18/54 [00:45<01:31,  2.54s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
#  37% 20/54 [00:50<01:25,  2.51s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  39% 21/54 [00:52<01:22,  2.51s/it]Files are up to date.
# Files are up to date.
#  93% 50/54 [02:04<00:09,  2.48s/it]Backup Complete: 1401 new, 0 updated, 0 deleted.
# Files are up to date.
# New best epoch 12 with smoothed loss_g 28.223 and loss_d 4.287
# zwanglos-v2-rode_nt1 | epoch=12 | step=648 | time=13:04:51 | training_speed=0:02:15 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.223 | smoothed_loss_disc=4.287
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_12e_648s_best_epoch.pth' (epoch 12 and step 648)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#   4% 2/54 [00:04<02:09,  2.50s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#   6% 3/54 [00:07<02:09,  2.54s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
#   7% 4/54 [00:10<02:05,  2.51s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  31% 17/54 [00:41<01:28,  2.40s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  33% 18/54 [00:43<01:26,  2.40s/it]Files are up to date.
# New best epoch 13 with smoothed loss_g 28.194 and loss_d 4.288
# zwanglos-v2-rode_nt1 | epoch=13 | step=702 | time=13:07:02 | training_speed=0:02:10 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.194 | smoothed_loss_disc=4.288
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_13e_702s_best_epoch.pth' (epoch 13 and step 702)
#   2% 1/54 [00:02<02:03,  2.32s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# An error occurred during backup: [Errno 2] No such file or directory: '/content/drive/MyDrive/ApplioBackup/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_12e_648s_best_epoch.pth'
# An error occurred during backup: [Errno 2] No such file or directory: '/content/drive/MyDrive/ApplioBackup/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_12e_648s_best_epoch.pth'
#   4% 2/54 [00:04<02:05,  2.42s/it]Files are up to date.
#  15% 8/54 [00:20<02:02,  2.66s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  19% 10/54 [00:25<01:53,  2.57s/it]Files are up to date.
# Files are up to date.
# New best epoch 14 with smoothed loss_g 28.166 and loss_d 4.285
# zwanglos-v2-rode_nt1 | epoch=14 | step=756 | time=13:09:18 | training_speed=0:02:15 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.166 | smoothed_loss_disc=4.285
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_14e_756s_best_epoch.pth' (epoch 14 and step 756)
#   2% 1/54 [00:02<02:04,  2.34s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 3/54 [00:07<02:07,  2.50s/it]Files are up to date.
#  56% 30/54 [01:15<01:00,  2.51s/it]Backup Complete: 4157 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  59% 32/54 [01:20<00:55,  2.50s/it]Files are up to date.
#  61% 33/54 [01:22<00:52,  2.51s/it]Backup Complete: 4157 new, 0 updated, 0 deleted.
#  63% 34/54 [01:25<00:50,  2.52s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Files are up to date.
#  94% 51/54 [02:06<00:07,  2.45s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 15 with smoothed loss_g 28.137 and loss_d 4.285
# zwanglos-v2-rode_nt1 | epoch=15 | step=810 | time=13:11:32 | training_speed=0:02:14 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.137 | smoothed_loss_disc=4.285
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_15e_810s_best_epoch.pth' (epoch 15 and step 810)
#   2% 1/54 [00:02<02:10,  2.47s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
#  81% 44/54 [01:46<00:24,  2.44s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  83% 45/54 [01:48<00:21,  2.44s/it]Files are up to date.
# New best epoch 16 with smoothed loss_g 28.109 and loss_d 4.284
# zwanglos-v2-rode_nt1 | epoch=16 | step=864 | time=13:13:44 | training_speed=0:02:11 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.109 | smoothed_loss_disc=4.284
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_16e_864s_best_epoch.pth' (epoch 16 and step 864)
#   4% 2/54 [00:04<02:03,  2.38s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 3/54 [00:07<02:04,  2.43s/it]Files are up to date.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   7% 4/54 [00:09<02:05,  2.52s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  35% 19/54 [00:46<01:24,  2.42s/it]Using HiFi-GAN vocoder
#  41% 22/54 [00:53<01:19,  2.49s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  43% 23/54 [00:56<01:16,  2.45s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 4.94 seconds.
#  74% 40/54 [01:38<00:33,  2.41s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  76% 41/54 [01:40<00:31,  2.42s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# New best epoch 17 with smoothed loss_g 28.082 and loss_d 4.283
# zwanglos-v2-rode_nt1 | epoch=17 | step=918 | time=13:15:57 | training_speed=0:02:12 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.082 | smoothed_loss_disc=4.283
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_17e_918s_best_epoch.pth' (epoch 17 and step 918)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 0 new, 1 updated, 1 deleted.
#   4% 2/54 [00:05<02:19,  2.67s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
#   6% 3/54 [00:07<02:07,  2.51s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#   7% 4/54 [00:10<02:03,  2.48s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  69% 37/54 [01:29<00:40,  2.38s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  70% 38/54 [01:31<00:38,  2.42s/it]Files are up to date.
# New best epoch 18 with smoothed loss_g 28.055 and loss_d 4.283
# zwanglos-v2-rode_nt1 | epoch=18 | step=972 | time=13:18:08 | training_speed=0:02:11 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.055 | smoothed_loss_disc=4.283
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_18e_972s_best_epoch.pth' (epoch 18 and step 972)
#   4% 2/54 [00:04<02:02,  2.36s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 3/54 [00:07<02:01,  2.39s/it]Files are up to date.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   7% 4/54 [00:09<02:02,  2.46s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   9% 5/54 [00:12<02:02,  2.50s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  56% 30/54 [01:12<00:55,  2.32s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 19 with smoothed loss_g 28.028 and loss_d 4.286
# zwanglos-v2-rode_nt1 | epoch=19 | step=1026 | time=13:20:20 | training_speed=0:02:11 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.028 | smoothed_loss_disc=4.286
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_19e_1026s_best_epoch.pth' (epoch 19 and step 1026)
#   2% 1/54 [00:02<02:11,  2.48s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
#  48% 26/54 [01:02<01:07,  2.41s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  50% 27/54 [01:05<01:05,  2.42s/it]Files are up to date.
# Files are up to date.
# New best epoch 20 with smoothed loss_g 28.001 and loss_d 4.284
# zwanglos-v2-rode_nt1 | epoch=20 | step=1080 | time=13:22:33 | training_speed=0:02:13 | lowest_value=25.989 (epoch 10 and step 502) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=28.001 | smoothed_loss_disc=4.284
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/G_2333333.pth' (epoch 20)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/D_2333333.pth' (epoch 20)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_20e_1080s_best_epoch.pth' (epoch 20 and step 1080)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_20e_1080s.pth' (epoch 20 and step 1080)
#  85% 46/54 [01:54<00:20,  2.50s/it]Backup Complete: 0 new, 4 updated, 1 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# New best epoch 21 with smoothed loss_g 27.970 and loss_d 4.285
# zwanglos-v2-rode_nt1 | epoch=21 | step=1134 | time=13:25:42 | training_speed=0:02:15 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.970 | smoothed_loss_disc=4.285
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_21e_1134s_best_epoch.pth' (epoch 21 and step 1134)
#  50% 27/54 [01:07<01:06,  2.46s/it]Backup Complete: 1 new, 2 updated, 0 deleted.
# Backup Complete: 1 new, 2 updated, 0 deleted.
# Backup Complete: 1 new, 2 updated, 0 deleted.
# Backup Complete: 1 new, 2 updated, 0 deleted.
# Backup Complete: 1 new, 2 updated, 0 deleted.
# Backup Complete: 1 new, 2 updated, 0 deleted.
#  56% 30/54 [01:15<01:01,  2.56s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  57% 31/54 [01:17<00:57,  2.51s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  85% 46/54 [01:53<00:18,  2.37s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  87% 47/54 [01:55<00:16,  2.38s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
#  89% 48/54 [01:58<00:14,  2.40s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  91% 49/54 [02:00<00:12,  2.41s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# New best epoch 22 with smoothed loss_g 27.939 and loss_d 4.287
# zwanglos-v2-rode_nt1 | epoch=22 | step=1188 | time=13:27:55 | training_speed=0:02:13 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.939 | smoothed_loss_disc=4.287
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_22e_1188s_best_epoch.pth' (epoch 22 and step 1188)
#   2% 1/54 [00:02<02:03,  2.32s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   7% 4/54 [00:09<02:04,  2.48s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   9% 5/54 [00:12<02:00,  2.46s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  72% 39/54 [01:34<00:36,  2.41s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 23 with smoothed loss_g 27.909 and loss_d 4.286
# zwanglos-v2-rode_nt1 | epoch=23 | step=1242 | time=13:30:07 | training_speed=0:02:11 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.909 | smoothed_loss_disc=4.286
# Backup Complete: 0 new, 1 updated, 1 deleted.
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_23e_1242s_best_epoch.pth' (epoch 23 and step 1242)
#   4% 2/54 [00:04<02:06,  2.44s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
#   6% 3/54 [00:07<02:04,  2.44s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   9% 5/54 [00:12<01:59,  2.44s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  59% 32/54 [01:17<00:52,  2.39s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 24 with smoothed loss_g 27.879 and loss_d 4.285
# zwanglos-v2-rode_nt1 | epoch=24 | step=1296 | time=13:32:19 | training_speed=0:02:11 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.879 | smoothed_loss_disc=4.285
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_24e_1296s_best_epoch.pth' (epoch 24 and step 1296)
#   0% 0/54 [00:00<?, ?it/s]Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
#  50% 27/54 [01:04<01:04,  2.40s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 25 with smoothed loss_g 27.849 and loss_d 4.281
# zwanglos-v2-rode_nt1 | epoch=25 | step=1350 | time=13:34:29 | training_speed=0:02:10 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.849 | smoothed_loss_disc=4.281
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_25e_1350s_best_epoch.pth' (epoch 25 and step 1350)
#   4% 2/54 [00:04<02:05,  2.42s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   6% 3/54 [00:07<02:03,  2.42s/it]Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Files are up to date.
# Files are up to date.
# Files are up to date.
#  43% 23/54 [00:55<01:14,  2.40s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
# New best epoch 26 with smoothed loss_g 27.820 and loss_d 4.280
# zwanglos-v2-rode_nt1 | epoch=26 | step=1404 | time=13:36:41 | training_speed=0:02:11 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.820 | smoothed_loss_disc=4.280
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_26e_1404s_best_epoch.pth' (epoch 26 and step 1404)
#   2% 1/54 [00:02<02:07,  2.41s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
#   4% 2/54 [00:04<02:01,  2.34s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#   7% 4/54 [00:09<02:03,  2.47s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 6.11 seconds.
#  30% 16/54 [00:39<01:33,  2.45s/it]Backup Complete: 0 new, 1 updated, 0 deleted.Backup Complete: 0 new, 1 updated, 0 deleted.
#
#  31% 17/54 [00:42<01:29,  2.42s/it]Files are up to date.Files are up to date.
#
# New best epoch 27 with smoothed loss_g 27.791 and loss_d 4.278
# zwanglos-v2-rode_nt1 | epoch=27 | step=1458 | time=13:38:53 | training_speed=0:02:12 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.791 | smoothed_loss_disc=4.278
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_27e_1458s_best_epoch.pth' (epoch 27 and step 1458)
#   7% 4/54 [00:09<01:58,  2.37s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   9% 5/54 [00:11<01:58,  2.41s/it]Files are up to date.
#  20% 11/54 [00:26<01:44,  2.43s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
#  22% 12/54 [00:28<01:42,  2.44s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
#  24% 13/54 [00:31<01:41,  2.46s/it]Files are up to date.
# New best epoch 28 with smoothed loss_g 27.762 and loss_d 4.275
# zwanglos-v2-rode_nt1 | epoch=28 | step=1512 | time=13:41:04 | training_speed=0:02:10 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.762 | smoothed_loss_disc=4.275
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_28e_1512s_best_epoch.pth' (epoch 28 and step 1512)
#   2% 1/54 [00:02<02:09,  2.44s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
# Backup Complete: 1 new, 1 updated, 0 deleted.
#   4% 2/54 [00:04<02:03,  2.37s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
#  17% 9/54 [00:21<01:48,  2.42s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
#  19% 10/54 [00:24<01:47,  2.45s/it]Files are up to date.
# Files are up to date.
#  85% 46/54 [01:50<00:18,  2.34s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  87% 47/54 [01:53<00:18,  2.61s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 3.92 seconds.
# New best epoch 29 with smoothed loss_g 27.734 and loss_d 4.270
# zwanglos-v2-rode_nt1 | epoch=29 | step=1566 | time=13:43:17 | training_speed=0:02:12 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.734 | smoothed_loss_disc=4.270
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_29e_1566s_best_epoch.pth' (epoch 29 and step 1566)
#   2% 1/54 [00:02<02:01,  2.29s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
#   4% 2/54 [00:04<02:03,  2.38s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.
#  33% 18/54 [00:43<01:27,  2.43s/it]Using HiFi-GAN vocoder
#  37% 20/54 [00:48<01:21,  2.40s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  39% 21/54 [00:51<01:20,  2.44s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 4.07 seconds.
#  57% 31/54 [01:16<00:55,  2.41s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  61% 33/54 [01:21<00:53,  2.57s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 6.30 seconds.
#  85% 46/54 [01:53<00:19,  2.40s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  87% 47/54 [01:56<00:17,  2.48s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 4.31 seconds.
#  93% 50/54 [02:04<00:10,  2.59s/it]Backup Complete: 0 new, 1 updated, 0 deleted.
# Backup Complete: 0 new, 1 updated, 0 deleted.
# Files are up to date.Files are up to date.
#
# New best epoch 30 with smoothed loss_g 27.706 and loss_d 4.267
# zwanglos-v2-rode_nt1 | epoch=30 | step=1620 | time=13:45:33 | training_speed=0:02:16 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.706 | smoothed_loss_disc=4.267
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Backup Complete: 0 new, 2 updated, 0 deleted.
# Converting audio 'assets/audios/SHORTENED-test.wav'...
# Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 2.73 seconds.
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/G_2333333.pth' (epoch 30)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/D_2333333.pth' (epoch 30)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_30e_1620s_best_epoch.pth' (epoch 30 and step 1620)
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_30e_1620s.pth' (epoch 30 and step 1620)
#  81% 44/54 [01:50<00:26,  2.61s/it]Backup Complete: 0 new, 4 updated, 1 deleted.
# Backup Complete: 0 new, 3 updated, 0 deleted.
# Backup Complete: 0 new, 3 updated, 0 deleted.
# Backup Complete: 0 new, 3 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
# Backup Complete: 0 new, 4 updated, 0 deleted.
#  91% 49/54 [02:02<00:12,  2.45s/it]Converting audio 'assets/audios/SHORTENED-test.wav'...
#  94% 51/54 [02:07<00:07,  2.46s/it]Conversion completed at 'assets/audios/SHORTENED-test_output.wav' in 5.53 seconds.
# New best epoch 31 with smoothed loss_g 27.679 and loss_d 4.267
# zwanglos-v2-rode_nt1 | epoch=31 | step=1674 | time=13:48:58 | training_speed=0:02:17 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.679 | smoothed_loss_disc=4.267
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_31e_1674s_best_epoch.pth' (epoch 31 and step 1674)
#  44% 24/54 [00:59<01:15,  2.53s/it]Backup Complete: 2 new, 2 updated, 1 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
# Backup Complete: 2 new, 2 updated, 0 deleted.
#  56% 30/54 [01:14<00:59,  2.48s/it]Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
# Backup Complete: 1 new, 0 updated, 0 deleted.
#  57% 31/54 [01:17<00:57,  2.49s/it]Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# Files are up to date.
# New best epoch 32 with smoothed loss_g 27.652 and loss_d 4.263
# zwanglos-v2-rode_nt1 | epoch=32 | step=1728 | time=13:51:12 | training_speed=0:02:13 | lowest_value=25.596 (epoch 21 and step 1131) | Number of epochs remaining for overtraining: g/total: 50 d/total: 100 | smoothed_loss_gen=27.652 | smoothed_loss_disc=4.263
# Saved model '/content/Applio/logs/zwanglos-v2-rode_nt1/zwanglos-v2-rode_nt1_32e_1728s_best_epoch.pth' (epoch 32 and step 1728)
#   7% 4/54 [00:09<01:55,  2.32s/it]Backup Complete: 1 new, 1 updated, 1 deleted.
# Files are up to date.
#  69% 37/54 [01:28<00:40,  2.37s/it]

# %% [markdown]
# ### **Extra**
# Enjoy extra options that can make it easier for you to use Applio

# %%
# !ln -s "/content/drive/MyDrive/voicemodel-source_rode_nt1_wav" "assets/datasets/voicemodel-source_rode_nt1_wav"
# !ln -s "/content/drive/MyDrive/voicemodel-source_metaglasses_wav" "assets/datasets/voicemodel-source_metaglasses_wav"
epochs = 150

# %%
# @title Mount Drive
# @markdown Mount the files from Google Drive to the Colab.
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title Auto Backup
# @markdown When running it, it will be activated or deactivated previously to start up together with Applio.
import os
import shutil
import time

LOGS_FOLDER = "/content/Applio/logs/"
GOOGLE_DRIVE_PATH = "/content/drive/MyDrive/ApplioBackup"

if "autobackups" not in globals():
    autobackups = False

cooldown = 15  # @param {type:"slider", min:0, max:100, step:0}
def backup_files():
    print("\nStarting backup loop...")
    last_backup_timestamps_path = os.path.join(
        LOGS_FOLDER, "last_backup_timestamps.txt"
    )
    fully_updated = False

    while True:
        try:
            updated_files = 0
            deleted_files = 0
            new_files = 0
            last_backup_timestamps = {}

            try:
                with open(last_backup_timestamps_path, "r") as f:
                    last_backup_timestamps = dict(line.strip().split(":") for line in f)
            except FileNotFoundError:
                pass

            for root, dirs, files in os.walk(LOGS_FOLDER):
                # Excluding "zips" and "mute" directories
                if "zips" in dirs:
                    dirs.remove("zips")
                if "mute" in dirs:
                    dirs.remove("mute")

                for filename in files:
                    if filename != "last_backup_timestamps.txt":
                        filepath = os.path.join(root, filename)
                        if os.path.isfile(filepath):
                            backup_filepath = os.path.join(
                                GOOGLE_DRIVE_PATH,
                                os.path.relpath(filepath, LOGS_FOLDER),
                            )
                            backup_folderpath = os.path.dirname(backup_filepath)
                            if not os.path.exists(backup_folderpath):
                                os.makedirs(backup_folderpath)
                            last_backup_timestamp = last_backup_timestamps.get(filepath)
                            current_timestamp = os.path.getmtime(filepath)
                            if (
                                last_backup_timestamp is None
                                or float(last_backup_timestamp) < current_timestamp
                            ):
                                shutil.copy2(filepath, backup_filepath)
                                last_backup_timestamps[filepath] = str(current_timestamp)
                                if last_backup_timestamp is None:
                                    new_files += 1
                                else:
                                    updated_files += 1


            for filepath in list(last_backup_timestamps.keys()):
                if not os.path.exists(filepath):
                    backup_filepath = os.path.join(
                        GOOGLE_DRIVE_PATH, os.path.relpath(filepath, LOGS_FOLDER)
                    )
                    if os.path.exists(backup_filepath):
                        os.remove(backup_filepath)
                        deleted_files += 1
                    del last_backup_timestamps[filepath]


            if updated_files > 0 or deleted_files > 0 or new_files > 0:
                print(f"Backup Complete: {new_files} new, {updated_files} updated, {deleted_files} deleted.")
                fully_updated = False
            elif not fully_updated:
                print("Files are up to date.")
                fully_updated = True

            with open(last_backup_timestamps_path, "w") as f:
                for filepath, timestamp in last_backup_timestamps.items():
                    f.write(f"{filepath}:{timestamp}\n")

            time.sleep(cooldown if fully_updated else 0.1)


        except Exception as error:
            print(f"An error occurred during backup: {error}")


if autobackups:
    autobackups = False
    print("Autobackup Disabled")
else:
    autobackups = True
    print("Autobackup Enabled")
# Out:
# Autobackup Disabled

# %%
# @title Load a Backup
import os
import shutil

# @markdown Put the exact name you put as your Model Name in Applio.
modelname = "zwanglos-v2-rode_nt1"  # @param {type:"string"}
source_path = "/content/drive/MyDrive/ApplioBackup/" + modelname
destination_path = "/content/Applio/logs/" + modelname
backup_timestamps_file = "last_backup_timestamps.txt"
if not os.path.exists(source_path):
    print(
        "The model folder does not exist. Please verify the name is correct or check your Google Drive."
    )
else:
    time_ = os.path.join("/content/drive/MyDrive/ApplioBackup/", backup_timestamps_file)
    time__ = os.path.join("/content/Applio/logs/", backup_timestamps_file)
    if os.path.exists(time_):
        shutil.copy(time_, time__)
    shutil.copytree(source_path, destination_path)
    print("Model backup loaded successfully.")
